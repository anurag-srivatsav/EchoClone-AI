# %%
# !pip install pyht
# !pip install google-generativeai

# %%
"""
Install the Google AI Python SDK

$ pip install google-generativeai
"""

import os
import google.generativeai as genai
from google.generativeai import configure, GenerativeModel



# Set your API key as an environment variable
os.environ['GENAI_API_KEY'] = 'AIzaSyDzeATPLWRenJGapH8wOCtKEs_QFf6FPR0'  # Replace with your actual API key

# Configure the SDK with the API key
api_key = os.getenv('GENAI_API_KEY')
configure(api_key=api_key)
# Create the model
generation_config = {
  "temperature": 1,
  "top_p": 0.95,
  "top_k": 64,
  "max_output_tokens": 8192,
  "response_mime_type": "text/plain",
}

model = genai.GenerativeModel(
  model_name="gemini-1.5-flash",
  generation_config=generation_config,
  # safety_settings = Adjust safety settings
  # See https://ai.google.dev/gemini-api/docs/safety-settings
)

chat_session = model.start_chat(
  history=[]
)
input1=input("enter your query: ")
response = chat_session.send_message(input1)

print(response.text)
# Out:
# enter your query: what is ml in 2 lines
# ML stands for Machine Learning, a type of Artificial Intelligence that enables computers to learn from data without explicit programming. It uses algorithms to identify patterns and make predictions, automating tasks and improving decision-making.

# %%
from pyht import Client
from pyht.client import TTSOptions
from IPython.display import Audio

# Initialize the client
client = Client(
   user_id="e6BvPrP9VGaGCHKY7io5o0KpKFr1",
   api_key="075e90e1e50049f09e5921962a24cda1"
)

# Provide the 'voice' argument when creating TTSOptions
# voice_url = "s3://voice-cloning-zero-shot/d9ff78ba-d016-47f6-b0ef-dd630f59414e/female-cs/manifest.json"
voice_url="s3://voice-cloning-zero-shot/71843e74-2087-4c61-855e-8e0ff1b03ef8/anurag/manifest.json"  # Replace with a valid voice URL or ID

# Create the TTSOptions object with the voice parameter
tts_options = TTSOptions(voice=voice_url)

# Save the audio to a file
output_file = "output_audio.wav"
with open(output_file, "wb") as audio_file:
    try:
        for chunk in client.tts(response.text, options=tts_options):
            audio_file.write(chunk)
        print(f"Audio saved to {output_file}")
    except Exception as e:
        print(f"An error occurred: {e}")

# Play the audio in Colab
Audio(output_file, autoplay=True)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-11-de0ca378de6c> in <cell line: 6>()
#       4
#       5 # Initialize the client
# ----> 6 client = Client(
#       7    user_id="e6BvPrP9VGaGCHKY7io5o0KpKFr1",
#       8    api_key="075e90e1e50049f09e5921962a24cda1"
#
# /usr/local/lib/python3.10/dist-packages/pyht/client.py in __init__(self, user_id, api_key, auto_connect, advanced)
#     273
#     274         if auto_connect:
# --> 275             self.refresh_lease()
#     276             self.warmup()
#     277
#
# /usr/local/lib/python3.10/dist-packages/pyht/client.py in refresh_lease(self)
#     342                     self._schedule_refresh()
#     343                 return
# --> 344             self._lease = self._lease_factory()
#     345
#     346             grpc_addr = self._advanced.grpc_addr or self._lease.metadata["inference_address"]
#
# ...

# %%
from pyht import Client
from pyht.client import TTSOptions
from IPython.display import Audio

# Initialize the client
client = Client(
   user_id="qotPLKt4h0WV1fLPmFHa75aYNpw2",
   api_key="b43eab925d5e485999c0657f97907b7e"
)

# Provide the 'voice' argument when creating TTSOptions
# voice_url = "s3://voice-cloning-zero-shot/d9ff78ba-d016-47f6-b0ef-dd630f59414e/female-cs/manifest.json"
voice_url="s3://voice-cloning-zero-shot/f41772f2-66d6-4127-a733-f2d621273740/original/manifest.json"  # Replace with a valid voice URL or ID

# Create the TTSOptions object with the voice parameter
tts_options = TTSOptions(voice=voice_url)

# Save the audio to a file
output_file = "output_audio.wav"
with open(output_file, "wb") as audio_file:
    try:
        for chunk in client.tts(response.text, options=tts_options):
            audio_file.write(chunk)
        print(f"Audio saved to {output_file}")
    except Exception as e:
        print(f"An error occurred: {e}")

# Play the audio in Colab
Audio(output_file, autoplay=True)
# Out:
# Audio saved to output_audio.wav
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
